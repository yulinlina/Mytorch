# %%
from Mytorch.trainer.trainer import Trainer
from Mytorch.data.data_loader import MnistData
from Mytorch.torch.mlp import MLP

# %%
data = MnistData(".\dataset\mnist_small_matlab.mat")
model =MLP()
model.show()
# Out:
# **********************************
# network: odict_keys(['linear1', 'f1', 'linear2', 'f2', 'linear3', 'f3'])
# w_dict: odict_keys(['linear1', 'linear2', 'linear3'])
# b_dict: odict_keys(['linear1', 'linear2', 'linear3'])
# z_dict: odict_keys(['f1', 'f2', 'f3'])
# a_dict: odict_keys(['f1', 'f2', 'f3'])
# **********************************

# %%
trainer =Trainer(max_epochs=10)
trainer.fit(model,data)
# Out:
# Epoch: 10/10, loss: 0.009  train_acc: 0.999  test_acc: 0.960  examples/sec:95.7
