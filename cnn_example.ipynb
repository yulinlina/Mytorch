# %%
from Mytorch.trainer.trainer import Trainer
from Mytorch.data.data_loader import MnistData
from Mytorch.torch.cnn import CNN

# %%
data = MnistData(".\dataset\mnist_small_matlab.mat",reshape=True)
model =CNN()
model.show()
# Out:
# **********************************
# network: odict_keys(['conv1', 'maxpoo1', 'f1', 'conv2', 'maxpoo2', 'f2', 'linear1', 'f3', 'linear2', 'f4'])
# w_dict: odict_keys(['conv1', 'conv2', 'linear1', 'linear2'])
# b_dict: odict_keys(['conv1', 'conv2', 'linear1', 'linear2'])
# z_dict: odict_keys(['f1', 'f2', 'f3', 'f4'])
# a_dict: odict_keys(['f1', 'f2', 'f3', 'f4'])
# **********************************

# %%
trainer =Trainer(max_epochs=3)
trainer.fit(model,data)
# Out:
# Epoch: 3,test_batch_id : 20,  test_acc: 0.100in_acc: 0.110
